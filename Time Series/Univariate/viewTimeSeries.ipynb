# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ts = np.loadtxt("/home/tbrownex/data/test/sinWave/sin.csv", delimiter=",")

# %%
period = ts[:,0]
value  = ts[:,1]

# %%
plt.plot(period, value)
