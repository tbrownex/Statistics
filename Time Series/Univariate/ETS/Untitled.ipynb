# %%
import numpy as np
from getConfig import getConfig
from getData import getData

# %%
config = getConfig()

# %%
df = getData(config)

# %%
import matplotlib.pyplot as plt

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(df["Sunblock"])
