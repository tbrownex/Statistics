# %%
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.4f}'.format

# %%
df = pd.read_csv("/home/tbrownex/results.csv")

# %%
df.corr()
# Out:
#              l1Size  dropout      lr     std  lambda  batchSize  dropoutTest  \
# l1Size       1.0000   0.0000 -0.0000  0.0000  0.0000     0.0000       0.0000
# dropout      0.0000   1.0000  0.0000  0.0000  0.0000     0.0000       0.0000
# lr          -0.0000   0.0000  1.0000  0.0000 -0.0000     0.0000       0.0000
# std          0.0000   0.0000  0.0000  1.0000  0.0000     0.0000       0.0000
# lambda       0.0000   0.0000 -0.0000  0.0000  1.0000     0.0000      -0.0000
# batchSize    0.0000   0.0000  0.0000  0.0000  0.0000     1.0000       0.0000
# dropoutTest  0.0000   0.0000  0.0000  0.0000 -0.0000     0.0000       1.0000
# rmse        -0.0987   0.3821  0.0398 -0.0124  0.6585    -0.0808      -0.0000
#
#                rmse
# l1Size      -0.0987
# dropout      0.3821
# lr           0.0398
# std         -0.0124
# lambda       0.6585
# batchSize   -0.0808
# dropoutTest -0.0000
# rmse         1.0000

# %%
df.sort_values("rmse").head()
# Out:
#      l1Size  dropout     lr    std  lambda optimizer  batchSize  dropoutTest  \
# 86       90   0.4000 0.0500 0.0100  0.0010      Adam         64       0.0500
# 124     120   0.4000 0.0100 0.0500  0.0010      Adam         64       0.0500
# 52       90   0.4000 0.0100 0.0500  0.0010      Adam         32       0.0500
# 76       90   0.4000 0.0100 0.0500  0.0010      Adam         64       0.0500
# 134     120   0.4000 0.0500 0.0100  0.0010      Adam         64       0.0500
#
#       rmse
# 86  2.9000
# 124 2.9300
# 52  2.9900
# 76  3.0000
# 134 3.0100

# %%
df.sort_values("rmse").tail()
# Out:
#      l1Size  dropout     lr    std  lambda optimizer  batchSize  dropoutTest  \
# 105     120   0.6000 0.0500 0.0500  0.0100      Adam         32       0.0500
# 106     120   0.4000 0.0500 0.0100  0.0100      Adam         32       0.0500
# 9        45   0.6000 0.0500 0.0500  0.0100      Adam         32       0.0500
# 131     120   0.6000 0.0500 0.0100  0.0100      Adam         64       0.0500
# 57       90   0.6000 0.0500 0.0500  0.0100      Adam         32       0.0500
#
#       rmse
# 105 4.1400
# 106 4.1600
# 9   4.1900
# 131 4.2200
# 57  4.4900
